# %%
## import turtle

## Set up a screen
screen = ##Fill
screen.setup(width = 600, height = 800) 
#Set screen title & bgcolor

##Fill Here


## set initial score
score_a = ##Fill
score_b = ##Fill


## Set player A paddle
paddle_a = ##Fill
paddle_a.speed(0)

paddle.shape(##Fill)
paddle.color(##Fill)

paddle_a.shapesize(stretch_wid = 5, stretch_len = 1)
#hide the lines
paddle_a._____##Fill Here
paddle_a.goto(##Fill, ##Fill)


## Set player B paddle
paddle_b.speed(0)
#Repeate code in paddle a

paddle_b.shapesize(stretch_wid = 5, stretch_len = 1)
paddle_b.goto(##Fill, ##Fill)
#Fill
    
    
    
    
## Set the Ball
ball = ##Fill
ball.speed(0)
ball.shape(##Fill Here)
ball.color(## Fill)
##Hide the lines
    
ball._____##Fill Here

ball.goto(##Fill , ##Fill)
ball.dx = 3
ball.dy = 3

# Functions 

def paddle_a_up():
    y = #Fill
    y = y + ##Fill
    paddle_a.sety(##Fill in)

def paddle_a_down():
    y = ##Fill
    y = y - ##Fill
    paddle_a.sety(##Fill in)
    
def paddle_b_up():
    y = #Fill
    y = y + ##Fill
    paddle_b.sety(##Fill in)
    
def paddle_b_down():
    y = ##Fill
    y = y - ##Fill
    paddle_b.sety(##Fill in)

# Keyboard bindings
screen.listen()
##Set paddle a up when pressing up arrow
#FILL 
        
##Set paddle a down pressing down arrow
#FILL 
    
##Set paddle b up when pressing w
#FILL 

##Set paddle b down when pressing s
#FILL 

# Main  game loop
while True:
    screen.update()
    #Move the ball
    ball.setx(##Fill)
    ball.sety(##Fill)
    

    #Border Checking
    ##Top and Bottom
    if ball.ycor()>___#Fill:
        ball.sety(##Fill)
        ball.dy = ball.dy * #FILL    


    elif ball.ycor()<____#Fill:
        #Fill, similar as above

    ## Left and right
    if ball.xcor()>___#Fill:
        score_a = #Fill
        pen.clear()
        pen.write("Player A: {}  Player B: {}".format(score_a, score_b)
                  , align="center", font=("Courier", 24, "normal"))
        ball.goto(#Fill , #Fill)
    elif ball.xcor()<____#Fill:
        score_b = #Fill
        pen.clear()
        pen.write("Player A: {}  Player B: {}".format(score_a, score_b)
                  , align="center", font=("Courier", 24, "normal"))
        ball.goto(#Fill , #Fill)

    #paddle border checking
    if paddle_a.ycor()+50 >= #Fill:
        paddle_a.sety(#Fill)
    if paddle_a.ycor()-50 <= #Fill:
        paddle_a.sety(#Fill)
    if paddle_b.ycor()+50 >= #Fill:
        paddle_b.sety(#Fill)
    if paddle_b.ycor()-50 <= #Fill:
        paddle_b.sety(#Fill)

    #Paddle and ball collisions
    if ##Fill:
        ball.dx = ball.dx * #Fill
    elif ##Fill:
        ball.dx = ball.dx * #Fill
# Out:
#   File "<ipython-input-1-57199f9cb37c>", line 8
#     paddle_a = ##Fill
#                      ^
# SyntaxError: invalid syntax
